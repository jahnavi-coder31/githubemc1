# %% [markdown]
# <a href="https://colab.research.google.com/github/jahnavi-coder31/githubemc1/blob/main/Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go

# %%
data = pd.read_csv("/content/Unemployment in India.csv")

# %%
data
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
data.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
data.tail()
# Out:
#     State Date Frequency  Estimated Unemployment Rate  Estimated Employed  \
# 763   NaN  NaN       NaN                          NaN                 NaN
# 764   NaN  NaN       NaN                          NaN                 NaN
# 765   NaN  NaN       NaN                          NaN                 NaN
# 766   NaN  NaN       NaN                          NaN                 NaN
# 767   NaN  NaN       NaN                          NaN                 NaN
#
#      Estimated Labour Participation Rate Region
# 763                                  NaN    NaN
# 764                                  NaN    NaN
# 765                                  NaN    NaN
# 766                                  NaN    NaN
# 767                                  NaN    NaN

# %%
data.columns = [
    "State",
    "Date",
    "Frequency",
    "Estimated Unemployment Rate",
    "Estimated Employed",
    "Estimated Labour Participation Rate",
    "Region"
    ]

# %%
data.tail()
# Out:
#     State Date Frequency  Estimated Unemployment Rate  Estimated Employed  \
# 763   NaN  NaN       NaN                          NaN                 NaN
# 764   NaN  NaN       NaN                          NaN                 NaN
# 765   NaN  NaN       NaN                          NaN                 NaN
# 766   NaN  NaN       NaN                          NaN                 NaN
# 767   NaN  NaN       NaN                          NaN                 NaN
#
#      Estimated Labour Participation Rate Region
# 763                                  NaN    NaN
# 764                                  NaN    NaN
# 765                                  NaN    NaN
# 766                                  NaN    NaN
# 767                                  NaN    NaN

# %%
data.shape
# Out:
# (768, 7)

# %%
data.columns
# Out:
# Index(['State', 'Date', 'Frequency', 'Estimated Unemployment Rate',
#        'Estimated Employed', 'Estimated Labour Participation Rate', 'Region'],
#       dtype='object')

# %%
data.describe()
# Out:
#        Estimated Unemployment Rate  Estimated Employed  \
# count                   740.000000        7.400000e+02
# mean                     11.787946        7.204460e+06
# std                      10.721298        8.087988e+06
# min                       0.000000        4.942000e+04
# 25%                       4.657500        1.190404e+06
# 50%                       8.350000        4.744178e+06
# 75%                      15.887500        1.127549e+07
# max                      76.740000        4.577751e+07
#
#        Estimated Labour Participation Rate
# count                           740.000000
# mean                             42.630122
# std                               8.111094
# min                              13.330000
# 25%                              38.062500
# 50%                              41.160000
# 75%                              45.505000
# max                              72.570000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
# ...

# %%
data.isnull().sum()
# Out:
# State                                  28
# Date                                   28
# Frequency                              28
# Estimated Unemployment Rate            28
# Estimated Employed                     28
# Estimated Labour Participation Rate    28
# Region                                 28
# dtype: int64

# %%
data.duplicated().any()
# Out:
# np.True_

# %%
data.State.value_counts()
# Out:
# State
# Andhra Pradesh      28
# Bihar               28
# Chhattisgarh        28
# Delhi               28
# Karnataka           28
# Gujarat             28
# Haryana             28
# Himachal Pradesh    28
# Jharkhand           28
# Maharashtra         28
# Madhya Pradesh      28
# Kerala              28
# West Bengal         28
# Uttar Pradesh       28
# Tripura             28
# Odisha              28
# Rajasthan           28
# Punjab              28
# Telangana           28
# Tamil Nadu          28
# Uttarakhand         27
# Meghalaya           27
# Assam               26
# Puducherry          26
# Goa                 24
# Jammu & Kashmir     21
# Sikkim              17
# Chandigarh          12
# Name: count, dtype: int64

# %%
data['Date'] = pd.to_datetime(data['Date'],dayfirst=True)

# %%
data['month_int'] = data['Date'].dt.month
data.head()
# Out:
#             State       Date Frequency  Estimated Unemployment Rate  \
# 0  Andhra Pradesh 2019-05-31   Monthly                         3.65
# 1  Andhra Pradesh 2019-06-30   Monthly                         3.05
# 2  Andhra Pradesh 2019-07-31   Monthly                         3.75
# 3  Andhra Pradesh 2019-08-31   Monthly                         3.32
# 4  Andhra Pradesh 2019-09-30   Monthly                         5.17
#
#    Estimated Employed  Estimated Labour Participation Rate Region  month_int
# 0          11999139.0                                43.24  Rural        5.0
# 1          11755881.0                                42.05  Rural        6.0
# 2          12086707.0                                43.50  Rural        7.0
# 3          12285693.0                                43.97  Rural        8.0
# 4          12256762.0                                44.68  Rural        9.0

# %%
import pandas as pd
import calendar


data = pd.read_csv('/content/Unemployment in India.csv')


print(data.columns)
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
import pandas as pd
import calendar


data = pd.read_csv('/content/Unemployment in India.csv')


data.columns = data.columns.str.strip()


data['Date'] = pd.to_datetime(data['Date'], dayfirst=True, errors='coerce')


data['month_int'] = data['Date'].dt.month


data['month'] = data['month_int'].apply(
    lambda x: calendar.month_abbr[int(x)] if pd.notnull(x) else None
)

print(data[['Date', 'month_int', 'month']].head())
# Out:
#         Date  month_int month
# 0 2019-05-31        5.0   May
# 1 2019-06-30        6.0   Jun
# 2 2019-07-31        7.0   Jul
# 3 2019-08-31        8.0   Aug
# 4 2019-09-30        9.0   Sep

# %%
import pandas as pd
import calendar


data = pd.read_csv('/content/Unemployment in India.csv')
data.columns = data.columns.str.strip()


data['Date'] = pd.to_datetime(data['Date'], dayfirst=True, errors='coerce')


data['month_int'] = data['Date'].dt.month
data['month'] = data['month_int'].apply(lambda x: calendar.month_abbr[int(x)] if pd.notnull(x) else None)


IND = data.groupby("month")[[
    'Estimated Unemployment Rate (%)',
    'Estimated Employed',
    'Estimated Labour Participation Rate (%)'
]].mean().reset_index()


print(IND.head())
# Out:
#   month  Estimated Unemployment Rate (%)  Estimated Employed  \
# 0   Apr                        23.641569        5.283320e+06
# 1   Aug                         9.637925        7.539815e+06
# 2   Dec                         9.497358        7.377388e+06
# 3   Feb                         9.964717        7.603996e+06
# 4   Jan                         9.950755        7.677344e+06
#
#    Estimated Labour Participation Rate (%)
# 0                                35.141176
# 1                                43.646792
# 2                                43.667358
# 3                                43.723019
# 4                                44.051321

# %%
import plotly.graph_objects as go


month = IND['month']
unemployment_rate = IND['Estimated Unemployment Rate (%)']
labour_participation_rate = IND['Estimated Labour Participation Rate (%)']


fig = go.Figure()


fig.add_trace(go.Bar(
    x=month,
    y=unemployment_rate,
    name="Unemployment Rate"
))

fig.add_trace(go.Bar(
    x=month,
    y=labour_participation_rate,
    name="Labour Participation Rate"
))


fig.update_layout(
    title="Unemployment Rate and Labour Participation Rate (Monthly)",
    xaxis_title="Month",
    yaxis_title="Percentage (%)",
    barmode='group',
    xaxis=dict(
        categoryorder='array',
        categoryarray=["Jan", "Feb", "Mar", "Apr", "May", "Jun",
                       "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
    )
)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

# %%
import plotly.express as px

fig = px.bar(
    IND,
    x='month',
    y='Estimated Employed',
    color='month',
    title='Estimated Employment by Month in India',
    labels={'Estimated Employed': 'Employed People'},
)

fig.update_layout(
    xaxis_title="Month",
    yaxis_title="Estimated Employed",
    xaxis=dict(categoryorder='array', categoryarray=[
        "Jan", "Feb", "Mar", "Apr", "May", "Jun",
        "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"
    ])
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data.columns = data.columns.str.strip()


State = data.groupby("Region")[[
    "Estimated Unemployment Rate (%)",
    "Estimated Employed",
    "Estimated Labour Participation Rate (%)"
]].mean()


State = State.reset_index()

print(State.head())
# Out:
#            Region  Estimated Unemployment Rate (%)  Estimated Employed  \
# 0  Andhra Pradesh                         7.477143        8.154093e+06
# 1           Assam                         6.428077        5.354772e+06
# 2           Bihar                        18.918214        1.236619e+07
# 3      Chandigarh                        15.991667        3.168312e+05
# 4    Chhattisgarh                         9.240357        4.303499e+06
#
#    Estimated Labour Participation Rate (%)
# 0                                39.375714
# 1                                44.868462
# 2                                38.153929
# 3                                39.336667
# 4                                42.810714

# %%
import plotly.express as px


data.columns = data.columns.str.strip()


fig = px.box(
    data,
    x='Region',
    y='Estimated Unemployment Rate (%)',
    color='Region',
    title='Unemployment Rate by State'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px


fig = px.bar(
    State,
    x='Region',
    y='Estimated Unemployment Rate (%)',
    color='Region',
    title='Average Unemployment Rate by State'
)


fig.update_layout(
    xaxis={'categoryorder': 'total descending'}
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px


fig = px.bar(
    data,
    x='Region',
    y='Estimated Unemployment Rate (%)',
    animation_frame='month',
    color='Region',
    title='Unemployment Rate from Jan 2020 to Oct 2020 (by State)'
)

fig.update_layout(
    xaxis={'categoryorder': 'total descending'}
)


fig.layout.updatemenus[0].buttons[0].args[1]["frame"]["duration"] = 2000

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
state_coords = {
    'Andhra Pradesh': (15.9129, 79.7400),
    'Bihar': (25.0961, 85.3131),
    'Delhi': (28.7041, 77.1025),
    'Gujarat': (22.2587, 71.1924),
    'Karnataka': (15.3173, 75.7139),
    'Kerala': (10.8505, 76.2711),
    'Madhya Pradesh': (22.9734, 78.6569),
    'Maharashtra': (19.7515, 75.7139),
    'Odisha': (20.9517, 85.0985),
    'Punjab': (31.1471, 75.3412),
    'Rajasthan': (27.0238, 74.2179),
    'Tamil Nadu': (11.1271, 78.6569),
    'Telangana': (18.1124, 79.0193),
    'Uttar Pradesh': (26.8467, 80.9462),
    'West Bengal': (22.9868, 87.8550),

}


data['latitude'] = data['Region'].map(lambda x: state_coords.get(x, (None, None))[0])
data['longitude'] = data['Region'].map(lambda x: state_coords.get(x, (None, None))[1])


data = data.dropna(subset=['latitude', 'longitude'])

# %%
import plotly.express as px


data.columns = data.columns.str.strip()


fig = px.scatter_geo(
    data,
    lon='longitude',
    lat='latitude',
    color='Region',
    size='Estimated Unemployment Rate (%)',
    animation_frame='month',
    scope='asia',
    hover_name='Region',
    title='Impact of Lockdown on Employment in India'
)

fig.layout.updatemenus[0].buttons[0].args[1]["frame"]["duration"] = 2000


fig.update_geos(
    lataxis_range=[5, 48],
    lonaxis_range=[65, 100],
    oceancolor="lightgrey",
    showocean=True
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data['Region'].unique()
# Out:
# array(['Andhra Pradesh', 'Bihar', 'Delhi', 'Gujarat', 'Karnataka',
#        'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Odisha', 'Punjab',
#        'Rajasthan', 'Tamil Nadu', 'Telangana', 'Uttar Pradesh',
#        'West Bengal'], dtype=object)

# %%
data.columns = data.columns.str.strip()


region = data.groupby("Region")[[
    "Estimated Unemployment Rate (%)",
    "Estimated Employed",
    "Estimated Labour Participation Rate (%)"
]].mean()


region = region.reset_index()


region.head()
# Out:
#            Region  Estimated Unemployment Rate (%)  Estimated Employed  \
# 0  Andhra Pradesh                         7.477143        8.154093e+06
# 1           Bihar                        18.918214        1.236619e+07
# 2           Delhi                        16.495357        2.627513e+06
# 3         Gujarat                         6.663929        1.140201e+07
# 4       Karnataka                         6.676071        1.066712e+07
#
#    Estimated Labour Participation Rate (%)
# 0                                39.375714
# 1                                38.153929
# 2                                38.929643
# 3                                46.101071
# 4                                41.345357

# %%
import plotly.express as px


data.columns = data.columns.str.strip()


fig = px.scatter_matrix(
    data,
    dimensions=[
        "Estimated Unemployment Rate (%)",
        "Estimated Employed",
        "Estimated Labour Participation Rate (%)"
    ],
    title="Scatter Matrix of Employment Indicators"
)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.express as px

# Load the dataset
data = pd.read_csv("/content/Unemployment in India.csv")  # Replace with your actual filename

# Clean column names
data.columns = data.columns.str.strip()

# Check column names (optional)
print(data.columns.tolist())

# Group by Region
region = data.groupby("Region")[["Estimated Unemployment Rate (%)"]].mean().reset_index()

# Plot bar chart
fig = px.bar(
    region,
    x='Region',
    y='Estimated Unemployment Rate (%)',
    color='Region',
    title="Average Unemployment Rate by Region"
)

fig.update_layout(
    xaxis={'categoryorder': 'total descending'}
)

fig.show()
# Out:
# ['Region', 'Date', 'Frequency', 'Estimated Unemployment Rate (%)', 'Estimated Employed', 'Estimated Labour Participation Rate (%)', 'Area']
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
import pandas as pd
import calendar


data.columns = data.columns.str.strip()


if 'month' not in data.columns:
    data['Date'] = pd.to_datetime(data['Date'], dayfirst=True, errors='coerce')
    data['month_int'] = data['Date'].dt.month
    data['month'] = data['month_int'].apply(lambda x: calendar.month_abbr[int(x)] if pd.notnull(x) else 'Unknown')


fig = px.bar(
    data,
    x='Region',
    y='Estimated Unemployment Rate (%)',
    color='Region',
    animation_frame='month',
    title='Unemployment Rate from Jan 2020 to Oct 2020 by Region'
)


fig.update_layout(
    xaxis={'categoryorder': 'total descending'}
)


fig.layout.updatemenus[0].buttons[0].args[1]['frame']['duration'] = 2000

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data.columns = data.columns.str.strip()


Unemployment = data.groupby('Region')['Estimated Unemployment Rate (%)'].mean().reset_index()


print(Unemployment.head())
# Out:
#            Region  Estimated Unemployment Rate (%)
# 0  Andhra Pradesh                         7.477143
# 1           Bihar                        18.918214
# 2           Delhi                        16.495357
# 3         Gujarat                         6.663929
# 4       Karnataka                         6.676071

# %%
Unemployment = data.groupby(['Region', 'Area'])['Estimated Unemployment Rate (%)'].mean().reset_index()

# %%
Unemployment = data.groupby(['Region'])['Estimated Unemployment Rate (%)'].mean().reset_index()

# %%
fig = px.sunburst(
    Unemployment,
    path=['Region'],
    values='Estimated Unemployment Rate (%)',
    title='Unemployment Rate by Region',
    height=650
)

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
before_lockdown = data[(data['month_int'] >= 1) & (data['month_int'] < 4)]
after_lockdown = data[(data['month_int'] >= 4) & (data['month_int'] < 6)]

# %%
after_lockdown = after_lockdown.groupby('Area')['Estimated Unemployment Rate (%)'].mean().reset_index()
before_lockdown = before_lockdown.groupby('Area')['Estimated Unemployment Rate (%)'].mean().reset_index()


lockdown = before_lockdown.merge(after_lockdown, on='Area')


lockdown.columns = ['Area', 'Unemployment rate before lockdown', 'Unemployment rate after lockdown']


lockdown.head()
# Out:
#     Area  Unemployment rate before lockdown  Unemployment rate after lockdown
# 0  Rural                           7.042444                         16.683333
# 1  Urban                           8.877556                         19.342000

# %%
lockdown['rate change in unemployment'] = round(
    (lockdown['Unemployment rate before lockdown'] - lockdown['Unemployment rate after lockdown'])
    / lockdown['Unemployment rate before lockdown'], 2
)


lockdown.head()
# Out:
#     Area  Unemployment rate before lockdown  Unemployment rate after lockdown  \
# 0  Rural                           7.042444                         16.683333
# 1  Urban                           8.877556                         19.342000
#
#    rate change in unemployment
# 0                        -1.37
# 1                        -1.18

# %%
import plotly.express as px

fig = px.bar(
    lockdown,
    x='Area',
    y='rate change in unemployment',
    color='rate change in unemployment',
    title='Percentage change in unemployment rate in each state after lockdown',
    template='ggplot2'
)

fig.update_layout(xaxis={'categoryorder': 'total descending'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
